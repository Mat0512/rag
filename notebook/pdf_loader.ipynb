# %%
import os
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# %%
#Read all the PDF from the directory

def process_all_documents(pdf_directory):
    all_documents = []
    pdf_dir = Path(pdf_directory)
    
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    print(f"Found {len(pdf_files)} PDF files to process")
    
    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        
        try: 
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()
        
        
        
        
        except Exception as e:
            print(f" X Error: {e}")

# %%
def process_all_documents(pdf_directory):
    
    all_documents = []
    pdf_dir = Path(pdf_directory)
    
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    
    print(f"files {pdf_files}")
    
    for pdf_file in pdf_files:
        print(f"processed file: {pdf_file}")
    
process_all_documents('../data/pdf')
# Out:
# procces files [WindowsPath('../data/pdf/Admin-Services-Advisory-No.-1.pdf'), WindowsPath('../data/pdf/Finalized_Resume.pdf')]
